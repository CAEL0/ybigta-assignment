# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://www.cine21.com/rank/person/content'

# %%
def actors_info(page):
    post_data = {}
    post_data['section'] = 'actor'
    post_data['period_start'] = '2021-07'
    post_data['gender'] = 'all'
    post_data['page'] = page
    
    res = requests.post(url, data=post_data)
    soup = BeautifulSoup(res.text, 'html.parser')
    actors = soup.select('li.people_li div.name')
    scores = soup.select('li.people_li > ul.num_info > li')
    movies = soup.select('ul.mov_list span')
    ranks = soup.select('span.grade')
    idx = 0
    actors_info_list = []
    
    for i in range(len(actors)):
        actor_info_dict = {}
        
        actor = actors[i].text
        name, appeared = actor[:actor.find('(')], int(actor[actor.find('(') + 1:-2])
        actor_info_dict['이름'] = name
        
        score = scores[i]
        actor_info_dict['흥행지수'] = int(score.strong.text.replace(',', ''))
        
        appear = []
        for _ in range(appeared):
            appear.append(movies[idx].text)
            idx += 1
        actor_info_dict['출연영화'] = appear
        
        actor_info_dict['랭킹'] = ranks[i].text
        
        link = 'http://www.cine21.com' + actors[i].a['href']
        res_actor = requests.get(link)
        soup_actor = BeautifulSoup(res_actor.text, 'html.parser')
        details = soup_actor.select_one('ul.default_info').select('li')
        
        for detail in details:
            key = detail.span.text
            value = detail.text.replace('\n', '')[len(key):]
            actor_info_dict[key] = value
        
        actors_info_list.append(actor_info_dict)
    
    return actors_info_list

# %%
result = []

for page in range(1, 11):
    result.extend(actors_info(page))

# %%
result
# Out:
# [{'이름': '김윤석',
#   '흥행지수': 128193,
#   '출연영화': ['모가디슈'],
#   '랭킹': '1',
#   '직업': '배우',
#   '생년월일': '1968-01-21',
#   '성별': '남',
#   '신장/체중': '178cm, 68kg',
#   '학교': '동의대학교 학사',
#   '취미': '여행, 낚시',
#   '소속사': '심엔터테인먼트'},
#  {'이름': '조인성',
#   '흥행지수': 112169,
#   '출연영화': ['모가디슈'],
#   '랭킹': '2',
#   '다른 이름': '趙寅成',
#   '직업': '배우',
#   '생년월일': '1981-07-28',
#   '성별': '남',
#   '신장/체중': '186cm, 72kg',
#   '학교': '전남과학대 모델이벤트과 - 동국대 연극영화 (중퇴)',
#   '취미': '모자모으기, 영화보기, 농구',
#   '특기': '농구, 태권도(공인 4단)',
#   '소속사': '싸이더스 HQ'},
#  {'이름': '허준호',
#   '흥행지수': 96147,
#   '출연영화': ['모가디슈', '국가부도의 날'],
#   '랭킹': '3',
#   '원어명': '許俊豪',
#   '직업': '배우',
#   '생년월일': '1964-03-03',
#   '성별': '남',
#   '신장/체중': '180cm, 75kg',
#   '학교': '서울예술대학 연극과',
#   '취미': '만화책 보기',
#   '특기': '야구, 농구',
#   '소속사': '지티비엔터테인먼트'},
#  {'이름': '조우진',
#   '흥행지수': 83490,
#   '출연영화': ['발신제한', '국가부도의 날'],
#   '랭킹': '4',
#   '다른 이름': '조신제',
#   '직업': '배우',
#   '생년월일': '1979-01-16',
#   '성별': '남'},
#  {'이름': '김소진',
#   '흥행지수': 80134,
#   '출연영화': ['모가디슈', '아이 캔 스피크'],
#   '랭킹': '5',
#   '직업': '배우',
#   '성별': '여'},
#  {'이름': '지창욱',
#   '흥행지수': 66823,
#   '출연영화': ['발신제한', '너의 이름은.', '조작된 도시'],
#   '랭킹': '6',
#   '직업': '배우',
#   '생년월일': '1987-07-05',
#   '성별': '남',
#   '홈페이지': 'https://twitter.com/jichangwookhttps://www.instagram.com/jichangwook/',
#   '신장/체중': '180cm, 65kg',
#   '학교': '단국대학교 공연영상학부',
#   '특기': '노래, 유도, 수영',
#   '소속사': '(주)글로리어스'},
#  {'이름': '정만식',
#   '흥행지수': 64097,
#   '출연영화': ['모가디슈'],
#   '랭킹': '7',
#   '직업': '배우',
#   '성별': '남'},
#  {'이름': '진경',
#   '흥행지수': 50094,
#   '출연영화': ['발신제한'],
#   '랭킹': '8',
#   '직업': '배우',
#   '생년월일': '1972-03-27',
#   '성별': '여'},
#  {'이름': '구교환',
#   '흥행지수': 48073,
#   '출연영화': ['모가디슈'],
#   '랭킹': '9',
#   '직업': '배우',
#   '생년월일': '1982-12-14',
#   '성별': '남'},
#  {'이름': '김재화',
#   '흥행지수': 34220,
#   '출연영화': ['모가디슈', '괴기맨숀', '액션히어로', '숏버스 이별행', '싱크홀', '소공녀'],
#   '랭킹': '10',
#   '직업': '배우',
#   '생년월일': '1980-09-01',
#   '성별': '여'},
#  {'이름': '이재인',
#   '흥행지수': 33397,
#   '출연영화': ['발신제한', '아이 캔 스피크'],
#   '랭킹': '11',
#   '직업': '배우',
#   '생년월일': '2004-02-06',
#   '성별': '여'},
#  {'이름': '김지호',
#   '흥행지수': 16698,
#   '출연영화': ['발신제한'],
#   '랭킹': '12',
#   '직업': '배우',
#   '생년월일': '1974-07-22',
#   '성별': '여',
#   '신장/체중': '167cm, 45kg',
#   '학교': '서울여자대학교 영문학',
#   '취미': '비디오 감상, 클래식 음반 모으기',
#   '특기': '수영, 영어회화',
#   '소속사': '이야기엔터테인먼트'},
#  {'이름': '박경혜',
#   '흥행지수': 16024,
#   '출연영화': ['모가디슈'],
#   '랭킹': '13',
#   '직업': '배우',
#   '생년월일': '1993-01-05',
#   '성별': '여',
#   '홈페이지': 'http://instagram.com/WO_WA_EYA'},
#  {'이름': '엄지원',
#   '흥행지수': 15457,
#   '출연영화': ['방법: 재차의', '기담'],
#   '랭킹': '14',
#   '다른 이름': 'Uhm Ji won',
#   '직업': '배우',
#   '생년월일': '1977-12-25',
#   '성별': '여',
#   '홈페이지': 'https://www.instagram.com/umjeewon/https://twitter.com/umjeewon',
#   '신장/체중': '170cm, 48kg',
#   '학교': '경북대학교 지리학과',
#   '취미': '수상스키, 독서',
#   '특기': '바이올린, 노래'},
#  {'이름': '정지소',
#   '흥행지수': 13462,
#   '출연영화': ['방법: 재차의'],
#   '랭킹': '15',
#   '다른 이름': '현승민',
#   '직업': '배우',
#   '생년월일': '1999-09-17',
#   '성별': '여'},
#  {'이름': '진기주',
#   '흥행지수': 12010,
#   '출연영화': ['미드나이트'],
#   '랭킹': '16',
#   '직업': '모델',
#   '생년월일': '1989-01-26',
#   '성별': '여',
#   '홈페이지': 'https://www.instagram.com/jinkijoo/',
#   '학교': '중앙대학교 컴퓨터공학부'},
#  {'이름': '정문성',
#   '흥행지수': 11539,
#   '출연영화': ['방법: 재차의'],
#   '랭킹': '17',
#   '직업': '배우',
#   '생년월일': '1981-01-13',
#   '성별': '남',
#   '학교': '순천향대학교 연극영화학 학사'},
#  {'이름': '위하준',
#   '흥행지수': 10008,
#   '출연영화': ['미드나이트'],
#   '랭킹': '18',
#   '직업': '배우',
#   '생년월일': '1991-08-05',
#   '성별': '남'},
#  {'이름': '김인권',
#   '흥행지수': 9616,
#   '출연영화': ['방법: 재차의'],
#   '랭킹': '19',
#   '직업': '배우',
#   '생년월일': '1978-01-20',
#   '성별': '남',
#   '홈페이지': 'https://twitter.com/inkwons',
#   '신장/체중': '175cm, 63kg',
#   '학교': '동국대학교 연극영화학'},
#  {'이름': '박훈',
#   '흥행지수': 8006,
#   '출연영화': ['미드나이트'],
#   '랭킹': '20',
#   '직업': '배우',
#   '성별': '남'},
#  {'이름': '고규필',
#   '흥행지수': 7693,
#   '출연영화': ['방법: 재차의', '감쪽같은 그녀'],
#   '랭킹': '21',
#   '직업': '배우',
#   '생년월일': '1982-05-02',
#   '성별': '남'},
#  {'이름': '길해연',
#   '흥행지수': 6005,
#   '출연영화': ['미드나이트', '잉투기'],
#   '랭킹': '22',
#   '직업': '배우',
#   '생년월일': '1965-00-00',
#   '성별': '여'},
#  {'이름': '오윤아',
#   '흥행지수': 5769,
#   '출연영화': ['방법: 재차의'],
#   '랭킹': '23',
#   '직업': '배우',
#   '생년월일': '1980-10-14',
#   '성별': '여',
#   '신장/체중': '172cm, 49kg',
#   '학교': '효성고등학교',
#   '소속사': '올리브나인'},
#  {'이름': '김혜윤',
#   '흥행지수': 4003,
#   '출연영화': ['미드나이트'],
#   '랭킹': '24',
#   '직업': '배우',
#   '생년월일': '1996-11-10',
#   '성별': '여',
#   '홈페이지': 'http://instagram.com/hye_yoon1110'},
#  {'이름': '권해효',
#   '흥행지수': 3856,
#   '출연영화': ['방법: 재차의', '배심원들', '후쿠오카', '국가부도의 날'],
#   '랭킹': '25',
#   '직업': '배우',
#   '생년월일': '1965-11-06',
#   '성별': '남',
#   '신장/체중': '170cm, 62kg',
#   '학교': '한양대학교 연극영화학 졸업'},
#  {'이름': '성준',
#   '흥행지수': 2779,
#   '출연영화': ['괴기맨숀'],
#   '랭킹': '26',
#   '직업': '배우',
#   '생년월일': '1990-07-10',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/thuggyduck/https://twitter.com/six2k',
#   '신장/체중': '187cm'},
#  {'이름': '김홍파',
#   '흥행지수': 2634,
#   '출연영화': ['괴기맨숀', '싱크홀', '배심원들', '국가부도의 날'],
#   '랭킹': '27',
#   '직업': '배우',
#   '생년월일': '1962-01-05',
#   '성별': '남'},
#  {'이름': '김보라',
#   '흥행지수': 2223,
#   '출연영화': ['괴기맨숀'],
#   '랭킹': '28',
#   '직업': '배우',
#   '생년월일': '1995-09-28',
#   '성별': '여',
#   '홈페이지': 'http://instagram.com/kim_bora95',
#   '신장/체중': '161cm'},
#  {'이름': '윤아영',
#   '흥행지수': 2121,
#   '출연영화': ['극장판 도라에몽: 진구의 신공룡', '도라에몽: 스탠바이미2'],
#   '랭킹': '29',
#   '직업': '성우',
#   '생년월일': '1986-04-08',
#   '성별': '여'},
#  {'이름': '송유현',
#   '흥행지수': 2003,
#   '출연영화': ['미드나이트', '혼자'],
#   '랭킹': '30',
#   '직업': '배우',
#   '성별': '여',
#   '홈페이지': 'http://instagram.com/lovely_hyun1218',
#   '신장/체중': '165cm, 50kg'},
#  {'이름': '이창훈',
#   '흥행지수': 1945,
#   '출연영화': ['괴기맨숀'],
#   '랭킹': '31',
#   '직업': '배우',
#   '생년월일': '1966-09-08',
#   '성별': '남',
#   '신장/체중': '178cm, 63kg',
#   '학교': '용산고등학교',
#   '취미': '비디오 감상, 공구 만들기',
#   '특기': '기계체조'},
#  {'이름': '이설',
#   '흥행지수': 1923,
#   '출연영화': ['방법: 재차의'],
#   '랭킹': '32',
#   '직업': '배우',
#   '생년월일': '1993-04-13',
#   '성별': '여'},
#  {'이름': '고두심',
#   '흥행지수': 1903,
#   '출연영화': ['빛나는 순간'],
#   '랭킹': '33',
#   '직업': '배우',
#   '생년월일': '1951-05-22',
#   '성별': '여',
#   '홈페이지': 'http://www.kodoosim.com/',
#   '신장/체중': '160cm',
#   '학교': '제주여자고등학교'},
#  {'이름': '김정아',
#   '흥행지수': 1856,
#   '출연영화': ['극장판 도라에몽: 진구의 신공룡', '도라에몽: 스탠바이미2'],
#   '랭킹': '34',
#   '직업': '성우',
#   '생년월일': '1974-12-06',
#   '성별': '여'},
#  {'이름': '박소진',
#   '흥행지수': 1762,
#   '출연영화': ['괴기맨숀', '좀비크러쉬: 헤이리'],
#   '랭킹': '35',
#   '원어명': '소진',
#   '다른 이름': "걸스데이;Girl's Day",
#   '직업': '가수',
#   '생년월일': '1986-05-21',
#   '성별': '여',
#   '홈페이지': 'https://twitter.com/girls_day_sojinhttps://instagram.com/ssozi_sojin/'},
#  {'이름': '최낙윤',
#   '흥행지수': 1591,
#   '출연영화': ['극장판 도라에몽: 진구의 신공룡', '도라에몽: 스탠바이미2'],
#   '랭킹': '36',
#   '직업': '성우',
#   '생년월일': '1984-01-27',
#   '성별': '남'},
#  {'이름': '이석형',
#   '흥행지수': 1545,
#   '출연영화': ['액션히어로', '괴기맨숀'],
#   '랭킹': '37',
#   '직업': '배우',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/leesukhyeong/'},
#  {'이름': '지현우',
#   '흥행지수': 1522,
#   '출연영화': ['빛나는 순간'],
#   '랭킹': '38',
#   '다른 이름': '주형태',
#   '직업': '배우',
#   '생년월일': '1984-11-29',
#   '성별': '남',
#   '홈페이지': 'https://twitter.com/star_mr_g',
#   '신장/체중': '187cm, 75kg',
#   '학교': '성균관대연기예술학과 재학',
#   '취미': '영화 감상',
#   '특기': '기타 연주'},
#  {'이름': '이현주',
#   '흥행지수': 1326,
#   '출연영화': ['극장판 도라에몽: 진구의 신공룡', '도라에몽: 스탠바이미2'],
#   '랭킹': '39',
#   '직업': '성우',
#   '성별': '여'},
#  {'이름': '윤다훈',
#   '흥행지수': 1288,
#   '출연영화': ['이번엔 잘 되겠지'],
#   '랭킹': '40',
#   '다른 이름': '남광우',
#   '직업': '배우',
#   '생년월일': '1964-12-30',
#   '성별': '남',
#   '신장/체중': '180cm, 72kg',
#   '학교': '한국방송통신대학교 법학',
#   '취미': '음악감상, 골프',
#   '소속사': 'SM엔터테인먼트'},
#  {'이름': '전혜진',
#   '흥행지수': 1142,
#   '출연영화': ['빛나는 순간'],
#   '랭킹': '41',
#   '직업': '배우',
#   '생년월일': '1988-06-17',
#   '성별': '여',
#   '홈페이지': 'https://www.instagram.com/mysky8282/',
#   '신장/체중': '170cm, 48kg',
#   '학교': '동국대학교 공연예술학 (재학)'},
#  {'이름': '서현우',
#   '흥행지수': 1123,
#   '출연영화': ['괴기맨숀', '혼자 사는 사람들', '배심원들'],
#   '랭킹': '42',
#   '직업': '배우',
#   '생년월일': '1983-11-20',
#   '성별': '남'},
#  {'이름': '이선진',
#   '흥행지수': 1074,
#   '출연영화': ['이번엔 잘 되겠지'],
#   '랭킹': '43',
#   '직업': '배우',
#   '생년월일': '1974-07-18',
#   '성별': '여',
#   '신장/체중': '175cm, 54kg',
#   '학교': '한양대학교언론정보대학원 광고홍보학',
#   '취미': '수상스키, 영화감상, 수영',
#   '특기': '볼링',
#   '소속사': '스쿨버스엔터테인먼트'},
#  {'이름': '조현정',
#   '흥행지수': 1061,
#   '출연영화': ['극장판 도라에몽: 진구의 신공룡', '도라에몽: 스탠바이미2'],
#   '랭킹': '44',
#   '직업': '성우',
#   '생년월일': '1978-07-25',
#   '성별': '여'},
#  {'이름': '김명국',
#   '흥행지수': 859,
#   '출연영화': ['이번엔 잘 되겠지'],
#   '랭킹': '45',
#   '직업': '배우',
#   '생년월일': '1963-03-02',
#   '성별': '남',
#   '학교': '서울예술대학 연극과'},
#  {'이름': '강유석',
#   '흥행지수': 834,
#   '출연영화': ['괴기맨숀'],
#   '랭킹': '46',
#   '직업': '배우',
#   '생년월일': '1994-06-10',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/youseok_/'},
#  {'이름': '이주영',
#   '흥행지수': 824,
#   '출연영화': ['액션히어로', '아무도 없는 곳'],
#   '랭킹': '47',
#   '직업': '배우',
#   '생년월일': '1987-04-24',
#   '성별': '여',
#   '홈페이지': 'https://www.instagram.com/izoo_young/'},
#  {'이름': '정재광',
#   '흥행지수': 806,
#   '출연영화': ['낫아웃', '파이프라인', '버티고'],
#   '랭킹': '48',
#   '직업': '배우',
#   '생년월일': '1990-00-00',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/jaekwang_jeong/'},
#  {'이름': '임은정',
#   '흥행지수': 796,
#   '출연영화': ['극장판 도라에몽: 진구의 신공룡', '도라에몽: 스탠바이미2'],
#   '랭킹': '49',
#   '직업': '성우',
#   '성별': '여'},
#  {'이름': '황정민',
#   '흥행지수': 782,
#   '출연영화': ['인질'],
#   '랭킹': '50',
#   '직업': '배우',
#   '생년월일': '1970-09-01',
#   '성별': '남',
#   '신장/체중': '180cm, 75kg',
#   '학교': '서울예술대학 연극과 졸업',
#   '특기': '농구, 악기연주',
#   '소속사': '예당엔터테인먼트'},
#  {'이름': '김중기',
#   '흥행지수': 761,
#   '출연영화': ['빛나는 순간'],
#   '랭킹': '51',
#   '직업': '배우',
#   '생년월일': '1979-07-22',
#   '성별': '남'},
#  {'이름': '함은정',
#   '흥행지수': 686,
#   '출연영화': ['아이윌 송'],
#   '랭킹': '52',
#   '다른 이름': '은정; 티아라',
#   '직업': '가수',
#   '생년월일': '1988-12-12',
#   '성별': '여',
#   '홈페이지': 'https://twitter.com/taraeunjung1212https://instagram.com/sweetgirlej/',
#   '신장/체중': '167cm, 47kg',
#   '학교': '동국대학교 공연예술학 휴학',
#   '소속사': '(주)코어콘텐츠미디어'},
#  {'이름': '이상훈',
#   '흥행지수': 644,
#   '출연영화': ['이번엔 잘 되겠지'],
#   '랭킹': '53',
#   '직업': '배우',
#   '생년월일': '1968-00-00',
#   '성별': '남'},
#  {'이름': '강하늘',
#   '흥행지수': 617,
#   '출연영화': ['비와 당신의 이야기'],
#   '랭킹': '54',
#   '다른 이름': '김하늘',
#   '직업': '배우',
#   '생년월일': '1990-02-21',
#   '성별': '남',
#   '홈페이지': 'http://weibo.com/galpos3?is_hot=1',
#   '신장/체중': '181cm, 70kg',
#   '학교': '중앙대학교 연극학과'},
#  {'이름': '이은자', '흥행지수': 611, '출연영화': ['학교 가는 길'], '랭킹': '55', '성별': '여'},
#  {'이름': '김정은',
#   '흥행지수': 537,
#   '출연영화': ['극장판 도라에몽: 진구의 신공룡', '바다 탐험대 옥토넛 시즌4: 바다 괴물 대소동', '도라에몽: 스탠바이미2'],
#   '랭킹': '56',
#   '직업': '성우',
#   '성별': '남'},
#  {'이름': '이규성',
#   '흥행지수': 534,
#   '출연영화': ['낫아웃'],
#   '랭킹': '57',
#   '직업': '배우',
#   '생년월일': '1992-00-00',
#   '성별': '남'},
#  {'이름': '정난모', '흥행지수': 489, '출연영화': ['학교 가는 길'], '랭킹': '58', '성별': '여'},
#  {'이름': '김서형',
#   '흥행지수': 460,
#   '출연영화': ['여고괴담 여섯번째 이야기: 모교'],
#   '랭킹': '59',
#   '직업': '배우',
#   '생년월일': '1976-10-28',
#   '성별': '여',
#   '신장/체중': '170cm, 49kg',
#   '학교': '영동전문대학 여성교양',
#   '취미': '헬스, 영화감상, 수영'},
#  {'이름': '정애화',
#   '흥행지수': 454,
#   '출연영화': ['갈매기'],
#   '랭킹': '60',
#   '직업': '배우',
#   '성별': '여'},
#  {'이름': '황인선',
#   '흥행지수': 429,
#   '출연영화': ['이번엔 잘 되겠지'],
#   '랭킹': '61',
#   '직업': '가수',
#   '생년월일': '1987-00-00',
#   '성별': '여',
#   '홈페이지': 'http://twitter.com/showworksinsunhttp://www.facebook.com/showworksinsunhttp://instagram.com/showworks_insun'},
#  {'이름': '천우희',
#   '흥행지수': 413,
#   '출연영화': ['비와 당신의 이야기', '버티고', '감쪽같은 그녀'],
#   '랭킹': '62',
#   '직업': '배우',
#   '생년월일': '1987-04-20',
#   '성별': '여',
#   '홈페이지': 'https://twitter.com/heeeya87https://www.instagram.com/thousand_wooo/',
#   '학교': '경기대학교 연기학'},
#  {'이름': '장인섭',
#   '흥행지수': 396,
#   '출연영화': ['액션히어로'],
#   '랭킹': '63',
#   '직업': '배우',
#   '생년월일': '1987-00-00',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/ssubx22'},
#  {'이름': '윤여정',
#   '흥행지수': 389,
#   '출연영화': ['죽어도 좋은 경험: 천사여 악녀가 되라', '미나리', '찬실이는 복도 많지', '하하하'],
#   '랭킹': '64',
#   '원어명': '윤여정',
#   '직업': '배우',
#   '생년월일': '1947-06-19',
#   '성별': '여',
#   '학교': '한양대학교 국문학 (중퇴)'},
#  {'이름': '양정원',
#   '흥행지수': 381,
#   '출연영화': ['빛나는 순간'],
#   '랭킹': '65',
#   '직업': '가수',
#   '성별': '남'},
#  {'이름': '조부용', '흥행지수': 367, '출연영화': ['학교 가는 길'], '랭킹': '66', '성별': '여'},
#  {'이름': '이상희',
#   '흥행지수': 364,
#   '출연영화': ['갈매기'],
#   '랭킹': '67',
#   '직업': '배우',
#   '성별': '남'},
#  {'이름': '김현수',
#   '흥행지수': 345,
#   '출연영화': ['여고괴담 여섯번째 이야기: 모교'],
#   '랭킹': '68',
#   '직업': '배우',
#   '생년월일': '2000-06-23',
#   '성별': '여'},
#  {'이름': '김태형',
#   '흥행지수': 343,
#   '출연영화': ['아이윌 송'],
#   '랭킹': '69',
#   '다른 이름': '구원',
#   '직업': '배우',
#   '생년월일': '1988-02-05',
#   '성별': '남',
#   '홈페이지': 'http://twitter.com/NA_Guwonhttp://instagram.com/guwon___'},
#  {'이름': '정진운',
#   '흥행지수': 339,
#   '출연영화': ['나만 보이니'],
#   '랭킹': '70',
#   '다른 이름': '2am; 진운',
#   '직업': '가수',
#   '생년월일': '1991-05-02',
#   '성별': '남',
#   '홈페이지': 'https://twitter.com/2amjinwoonhttps://www.facebook.com/jinwoon.jeonghttps://instagram.com/jinwoon52',
#   '신장/체중': '185cm, 72kg',
#   '학교': '대진대학교 연극영화학',
#   '취미': '악기다루기',
#   '특기': '기타, 베이스, 드럼 연주, 농구',
#   '소속사': 'JYP엔터테인먼트'}]
